# %% [markdown]
# # 📊 Data Visualization Portfolio — Interactive Notebook
#
# This notebook provides an interactive walkthrough of all six charts.
# Run cells in order, or jump to any section.
#
# | Section | Chart |
# |---------|-------|
# | 1 | Climate Anomaly |
# | 2 | E-Commerce Sales |
# | 3 | Customer Segments |
# | 4 | Stock Dashboard |
# | 5 | Survey Radar |
# | 6 | Revenue Distributions |

# %%
import sys
sys.path.insert(0, '../src')

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.dpi'] = 120
print('Environment ready ✓')

# %% [markdown]
# ## 1 · Global Temperature Anomaly

# %%
from visualizations.chart_01_climate import render
fig = render(save=False)

# %% [markdown]
# ## 2 · E-Commerce Revenue Dashboard

# %%
from visualizations.chart_02_ecommerce import render
fig = render(save=False)

# %% [markdown]
# ## 3 · Customer RFM Segmentation

# %%
from visualizations.chart_03_segments import render
fig = render(save=False)

# %% [markdown]
# ## 4 · Stock Performance Dashboard

# %%
from visualizations.chart_04_stocks import render
fig = render(save=False)

# %% [markdown]
# ## 5 · Employee Satisfaction Survey (Radar)

# %%
from visualizations.chart_05_survey import render
fig = render(save=False)

# %% [markdown]
# ## 6 · Revenue Distribution Analysis

# %%
from visualizations.chart_06_distributions import render
fig = render(save=False)

# %% [markdown]
# ---
# ## Build All & Save
# Run the cell below to regenerate all PNGs to `assets/images/`.

# %%
import build_all
build_all.main()
